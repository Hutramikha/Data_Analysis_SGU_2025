# %% [markdown]
# # **Exploratory Data Analysis (EDA) in Python**

# %% [markdown]
# ## **Giới thiệu**

# %% [markdown]
# Phân tích khám phá dữ liệu được thực hiện trên bộ dữ liệu theo dõi bệnh tiểu đường, bao gồm các thông tin về thời gian, loại chỉ số (Code), và giá trị đo lường (Value). Dữ liệu được thu thập từ nhiều file nhỏ, mỗi file chứa các bản ghi theo định dạng chuỗi thời gian.
#
# Các trường dữ liệu chính:
#
#     Date: Ngày ghi nhận
#     Time: Giờ ghi nhận
#     Code: Mã loại chỉ số (ví dụ: glucose, insulin, hoạt động thể chất…)
#     Value: Giá trị đo lường tương ứng

# %% [markdown]
# **Phân tích dữ liệu ban đầu**

# %% [markdown]
# Cách thực hiện: Sử dụng các thư viện mạnh mẽ của Python

# %%
# import thư viện pandas, và các module cần thiết khác
import pandas as pd
import glob

# %% [markdown]
# ## **Load the dataset**

# %%
# Đọc tất cả các file
files = glob.glob("lab3/file/diabetes-data/diabetes-data/data-*")

df_list = []
for file in files:
    df = pd.read_csv(file, sep="\t", header=None, names=["Date", "Time", "Code", "Value"])
    df_list.append(df)

df = pd.concat(df_list, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Đọc tất cả các file
# ----> 2 files = glob.glob("lab3/file/diabetes-data/diabetes-data/data-*")
#       4 df_list = []
#       5 for file in files:
#
# NameError: name 'glob' is not defined
